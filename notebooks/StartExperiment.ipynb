# %%
import sys
sys.path.append('../code/')
import ExperimentRunner
import time

# %%
start = time.time()
testExp = ExperimentRunner.ExperimentRunner()
print time.time() - start
# Out:
# importing train + test data...
# done
# 0.00633811950684

# %%
testExp.run_fast_NGK_test(12)
# Out:
# classifying for NGK
# pre-train
# pre-predic
# post-predict
# (array([ 0.64864865,  1.        ,  0.92307692,  0.91666667]),
#  array([ 0.96 ,  0.4  ,  0.8  ,  0.825]),
#  array([ 0.77419355,  0.57142857,  0.85714286,  0.86842105]))

# %%
testExp.run_fast_WK_test()
# Out:
# classifying for WK
# pre-train
# pre-predic
# post-predict
# (array([ 0.82142857,  1.        ,  0.82352941,  1.        ]),
#  array([ 0.92      ,  0.8       ,  0.93333333,  0.925     ]),
#  array([ 0.86792453,  0.88888889,  0.875     ,  0.96103896]))

# %%
start = time.time()
testExp.get_save_SSKMat_upto(3,0.5,"../results/test/quick")
print time.time() - start
# Out:
# computing Gram matrices
# Train row 10 of 380
#
# Train row 20 of 380
#
# Train row 30 of 380
#
# Train row 40 of 380
#
# Train row 50 of 380
#
# Train row 60 of 380
#
# Train row 70 of 380
#
# Train row 80 of 380
#
# Train row 90 of 380
#
# Train row 100 of 380
#
# Train row 110 of 380
#
# Train row 120 of 380
#
# Train row 130 of 380
#
# Train row 140 of 380
#
# Train row 150 of 380
#
# Train row 160 of 380
#
# Train row 170 of 380
#
# Train row 180 of 380
#
# Train row 190 of 380
#
# Train row 200 of 380
#
# Train row 210 of 380
#
# Train row 220 of 380
#
# Train row 230 of 380
#
# Train row 240 of 380
#
# Train row 250 of 380
#
# Train row 260 of 380
#
# Train row 270 of 380
#
# Train row 280 of 380
#
# Train row 290 of 380
#
# Train row 300 of 380
#
# Train row 310 of 380
#
# Train row 320 of 380
#
# Train row 330 of 380
#
# Train row 340 of 380
#
# Train row 350 of 380
#
# Train row 360 of 380
#
# Train row 370 of 380
#
# Train row 380 of 380
#
# Test row 10 of 90
#
# Test row 20 of 90
#
# Test row 30 of 90
#
# Test row 40 of 90
#
# Test row 50 of 90
#
# Test row 60 of 90
#
# Test row 70 of 90
#
# Test row 80 of 90
#
# Test row 90 of 90
#
# saved SSKs up to  3 in:  ../results/test/quick
# 2611.37276816

# %%
start = time.time()
testExp.run_SSK_test(3,0.5)
print time.time() - start

# %%
#This seems to be taking forever... find out why
testExp.run_SSK_test(3,0.5,"../results/test/quick3")
# Out:
# classifying for SSK
# pre-train
# pre-predic
# post-predict
# (array([ 0.8       ,  1.        ,  0.66666667,  1.        ]),
#  array([ 0.96      ,  0.6       ,  0.93333333,  0.825     ]),
#  array([ 0.87272727,  0.75      ,  0.77777778,  0.90410959]))

# %%
testExp.run_SSK_test(5,0.5)

# %%
testExp.run_SSK_k_Combi_test(k1=3,k2=4,lamb=0.5)

# %%
testExp.run_SSK_lam_Combi_test(k=5, lam1=0.05,lam2=0.5)

# %%
testExp.run_SSK_NGK_Combi_test(k=5,wSSK=0.2,wNGK=0.8,lamb=0.5)

# %%
#don't run this either for now as it uses SSK
#testExp.run_full_test(2,0.5)

# %%
#save computed Gram matrix
testExp.save_WK_Gram("WKPaperDat")

# %%
#run test using pre-computed Gram, without re-calculating it
testExp.run_WK_test("WKPaperDat")

# %%
testExp.save_NGK_Gram("NGK1")

# %%
testExp.run_NGK_test(3, "NGK1")
