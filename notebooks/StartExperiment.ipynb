# %%
import sys
sys.path.append('../code/')
import ExperimentRunner
import time

# %%
start = time.time()
testExp = ExperimentRunner.ExperimentRunner()
print time.time() - start
# Out:
# importing train + test data...
# done
# 0.00573492050171

# %%
testExp.run_SSK_NGK_Combi_test("../results/test/full5", 0, 1)
# Out:
# computing Gram matrices
# NGK...
# NGK + SSK...
# done
# classifying for SSK + NGK
# pre-train
# pre-predic
# post-predict

# %%
testExp.run_SSK_k_Combi_test("../results/test/full8", "../results/test/full10")
# Out:
# done
# classifying for SSK
# pre-train
# pre-predic
# post-predict

# %%
testExp.run_fast_NGK_test(7)
# Out:
# classifying for NGK
# pre-train
# pre-predic
# post-predict
# (array([ 0.92307692,  1.        ,  0.92857143,  0.975     ]),
#  array([ 0.96      ,  1.        ,  0.86666667,  0.975     ]),
#  array([ 0.94117647,  1.        ,  0.89655172,  0.975     ]))

# %%
start = time.time()
testExp.get_save_SSKMat_upto(14, 0.5,"../results/test4/split1_8")
print time.time() - start
# Out:
# computing Gram matrices
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-cbfa700167c8> in <module>()
#       1 start = time.time()
# ----> 2 testExp.get_save_SSKMat_upto(14, 0.5,"../results/test4/split1_8")
#       3 print time.time() - start
#
# /home/manttari/Documents/aml/Project/newWorking/string-kernels/code/ExperimentRunner.pyc in get_save_SSKMat_upto(self, k, lamb, SSKGramFileName)
#     368                 print "Train row %d of %d\n" % ( i+1, len(self.TrainDocVals) )
#     369             for j in xrange(i,len(self.TrainDocVals)):
# --> 370                 ssksUpTo = ssk.sskUpTo(str(self.TrainDocVals[i]), str(self.TrainDocVals[j]), k, lamb)
#     371                 for ki in range(0,k+1):
#     372                     self.SSKTrainGramUpTo[ki][i][j] = ssksUpTo[ki]
#
# KeyboardInterrupt:

# %%
testExp.run_fast_WK_test()
# Out:
# classifying for WK
# pre-train
# pre-predic
# post-predict
# (array([ 0.82142857,  1.        ,  0.82352941,  1.        ]),
#  array([ 0.92      ,  0.8       ,  0.93333333,  0.925     ]),
#  array([ 0.86792453,  0.88888889,  0.875     ,  0.96103896]))

# %%
start = time.time()
testExp.run_SSK_test(3,0.5)
print time.time() - start

# %%
#This seems to be taking forever... find out why
testExp.run_SSK_test(3,0.5,"../results/test4/split1_12")
# Out:
# classifying for SSK
# pre-train
# pre-predic
# post-predict
# (array([ 0.58536585,  1.        ,  1.        ,  0.975     ]),
#  array([ 0.96      ,  0.2       ,  0.46666667,  0.975     ]),
#  array([ 0.72727273,  0.33333333,  0.63636364,  0.975     ]))

# %%
testExp.run_SSK_test(5,0.5)

# %%
testExp.run_SSK_k_Combi_test(k1=3,k2=4,lamb=0.5)

# %%
testExp.run_SSK_lam_Combi_test(k=5, lam1=0.05,lam2=0.5)

# %%
testExp.run_SSK_NGK_Combi_test(k=5,wSSK=0.2,wNGK=0.8,lamb=0.5)

# %%
#don't run this either for now as it uses SSK
#testExp.run_full_test(2,0.5)

# %%
#save computed Gram matrix
testExp.save_WK_Gram("WKPaperDat")

# %%
#run test using pre-computed Gram, without re-calculating it
testExp.run_WK_test("WKPaperDat")

# %%
testExp.save_NGK_Gram("NGK1")

# %%
testExp.run_NGK_test(3, "NGK1")
