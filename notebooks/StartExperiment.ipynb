# %%
import sys
sys.path.append('../code/')
import ExperimentRunner

# %%
testExp = ExperimentRunner.ExperimentRunner()
testExp.run_test(2,0.5)
# Out:
# importing train + test data...
# done
# computing Gram matrices
# Train row 10 of 40
#
# Train row 20 of 40
#
# Train row 30 of 40
#
# Train row 40 of 40
#
# Test row 10 of 40
#
# Test row 20 of 40
#
# Test row 30 of 40
#
# Test row 40 of 40
#
# done
# classifying for WK
