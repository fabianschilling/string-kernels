# %%
import sys
sys.path.append('../code/')
import ExperimentRunner

# %%
testExp = ExperimentRunner.ExperimentRunner()
# Out:
# importing train + test data...
# done

# %%
testExp.run_NGK_test(3)
# Out:
# computing Gram matrices
# Train row 10 of 40
#
# Train row 20 of 40
#
# Train row 30 of 40
#
# Train row 40 of 40
#
# Test row 10 of 40
#
# Test row 20 of 40
#
# Test row 30 of 40
#
# Test row 40 of 40
#
# done
# classifying for NGK
# (array([ 1.        ,  0.43478261,  1.        ,  1.        ]),
#  array([ 0.5,  1. ,  0.4,  0.8]),
#  array([ 0.66666667,  0.60606061,  0.57142857,  0.88888889]))

# %%
testExp.run_WK_test()
# Out:
# computing Gram matrices
# Train row 10 of 40
#
# Train row 20 of 40
#
# Train row 30 of 40
#
# Train row 40 of 40
#
# Test row 10 of 40
#
# Test row 20 of 40
#
# Test row 30 of 40
#
# Test row 40 of 40
#
# done
# classifying for WK
# (array([ 1.        ,  0.83333333,  1.        ,  1.        ]),
#  array([ 0.9,  1. ,  0.9,  1. ]),
#  array([ 0.94736842,  0.90909091,  0.94736842,  1.        ]))

# %%
#This seems to be taking forever... find out why
#testExp.run_SSK_test(2,0.5)

# %%
#don't run this either for now as it uses SSK
#testExp.run_full_test(2,0.5)
# Out:
# computing Gram matrices
# 0.5 2
# 0.5 2
# 0.5 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-eb1144ad88f4> in <module>()
# ----> 1 testExp.run_full_test(2,0.5)
#
# /home/manttari/Documents/aml/Project/string-kernels/code/ExperimentRunner.py in run_full_test(self, k, lamb)
#     193             lamb: Decay factor for SSK
#     194           """
# --> 195         self.compute_gram_matrices(k,lamb)
#     196         WKres = self.do_classification(self.WKTrainGram, self.WKTestGram, 'WK')
#     197         NGKres = self.do_classification(self.NGKTrainGram, self.NGKTestGram, 'NGK')
#
# /home/manttari/Documents/aml/Project/string-kernels/code/ExperimentRunner.py in compute_gram_matrices(self, k, lamb, WK, NGK, SSK)
#     151                     self.NGKTrainGram[i][j] = ngk.ngk(self.TrainDocVals[i], self.TrainDocVals[j], k)
#     152                 if(SSK):
# --> 153                     self.SSKTrainGram[i][j] = ssk.ssk(self.TrainDocVals[i], self.TrainDocVals[j], k, lamb)
#     154         for i in xrange( 0, len(self.TestDocVals) ):
#     155             if( (i+1)%10 == 0 ):
#
# /home/manttari/Documents/aml/Project/string-kernels/code/ssk.pyc in ssk(doc1, doc2, k, lam)
#      70     doc_t = [doc2, doc2]
#      71     norms[0] = get_kernel(doc_s, k, lam)
# ---> 72     norms[1] = get_kernel(doc_t, k, lam)
#      73
#      74     for i in xrange(2):
#
# /home/manttari/Documents/aml/Project/string-kernels/code/ssk.pyc in get_kernel(docs, k, lam)
#      16         for i in xrange(len_s+1):
#      17             for j in xrange(len_t+1):
# ---> 18                 kd[m][i][j] = (m + 1) % 2
#      19
#      20 #  Calculate Kd and Kdd
#
# KeyboardInterrupt:
